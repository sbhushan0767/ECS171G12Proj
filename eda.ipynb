# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in processed data
df = pd.read_csv('./datasets/credit.csv')

# %%
# Preview data
df
# Out:
#         Loan ID  Customer ID  Loan Status  Current Loan Amount  Term  \
# 0      0.081780     0.595049          1.0             0.004342   1.0
# 1      0.309687     0.371241          1.0             1.000000   1.0
# 2      0.467604     0.903503          1.0             0.003365   0.0
# 3      0.153952     0.565467          1.0             0.002064   1.0
# 4      0.544380     0.686408          1.0             0.005376   1.0
# ...         ...          ...          ...                  ...   ...
# 34968  0.964449     0.784434          1.0             0.003179   1.0
# 34969  0.989857     0.991461          1.0             0.001976   1.0
# 34970  0.622878     0.432795          1.0             0.001641   1.0
# 34971  0.653277     0.875362          1.0             0.002053   0.0
# 34972  0.733483     0.650039          1.0             0.001917   1.0
#
#        Credit Score  Annual Income  Years in current job  Home Ownership  \
# 0          0.746988       0.029970                   0.8        0.333333
# 1          0.939759       0.059213                   0.8        0.666667
# 2          0.819277       0.020064                   0.3        0.666667
# 3          0.873494       0.030429                   0.0        0.333333
# 4          0.560241       0.068202                   0.2        1.000000
# ...             ...            ...                   ...             ...
# 34968      0.765060       0.035894                   0.6        0.333333
# 34969      0.807229       0.023069                   0.5        1.000000
# 34970      0.963855       0.036888                   1.0        0.333333
# 34971      0.542169       0.047214                   0.2        0.333333
# 34972      0.795181       0.038012                   0.2        0.333333
#
#         Purpose  Monthly Debt  Years of Credit History  \
# 0      0.333333      0.011965                 0.202096
# 1      0.200000      0.066998                 0.167665
# 2      0.200000      0.020057                 0.124251
# 3      0.200000      0.024906                 0.238024
# 4      0.200000      0.042814                 0.282934
# ...         ...           ...                      ...
# 34968  0.400000      0.032263                 0.167665
# 34969  0.200000      0.031710                 0.571856
# 34970  0.200000      0.031751                 0.309880
# 34971  0.333333      0.065421                 0.281437
# 34972  0.200000      0.048300                 0.356287
#
#        Months since last delinquent  Number of Open Accounts  \
# 0                          0.198310                 0.066667
# 1                          0.164773                 0.226667
# 2                          0.198310                 0.106667
# 3                          0.056818                 0.160000
# 4                          0.187500                 0.040000
# ...                             ...                      ...
# 34968                      0.198310                 0.146667
# 34969                      0.267045                 0.120000
# 34970                      0.198310                 0.120000
# 34971                      0.198310                 0.280000
# 34972                      0.357955                 0.120000
#
#        Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 0                       0.066667                0.014053             0.000271
# 1                       0.066667                0.018352             0.000487
# 2                       0.000000                0.015786             0.000251
# 3                       0.066667                0.007524             0.000177
# 4                       0.000000                0.026924             0.000360
# ...                          ...                     ...                  ...
# 34968                   0.000000                0.005906             0.000238
# 34969                   0.066667                0.004162             0.000092
# 34970                   0.000000                0.016463             0.000728
# 34971                   0.000000                0.019296             0.000815
# 34972                   0.066667                0.006428             0.000193
#
#        Bankruptcies  Tax Liens Credit Score Range
# 0          0.142857        0.0     (701.2, 717.8]
# 1          0.000000        0.0     (734.4, 751.0]
# 2          0.000000        0.0     (717.8, 734.4]
# 3          0.142857        0.0     (717.8, 734.4]
# 4          0.000000        0.0     (668.0, 684.6]
# ...             ...        ...                ...
# 34968      0.000000        0.0     (701.2, 717.8]
# 34969      0.142857        0.0     (717.8, 734.4]
# 34970      0.000000        0.0     (734.4, 751.0]
# 34971      0.000000        0.0     (668.0, 684.6]
# 34972      0.142857        0.0     (701.2, 717.8]
#
# [34973 rows x 20 columns]

# %%
for col in df.columns:
    if (col != 'Credit Score'):
        df.plot.scatter(x=col, y='Credit Score', c='DarkBlue',figsize=(15,8))

# %%
for col in df.columns:
    if (col != 'Credit Score Range'):
        plt.figure(figsize=(15,8))
        ax = sns.boxplot(x="Credit Score Range", y=col, data=df)
        plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, linewidths=.5, ax=ax)
